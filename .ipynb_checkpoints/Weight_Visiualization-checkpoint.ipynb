# %%
# %matplotlib inline
# non-specific libraies
import matplotlib.pyplot as plt
import numpy as np

import weight_visiualize as wv
import midlayer
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Linear model weights

# %%
np_weights = wv.first_weight_linear(0)
print('done.')
# Out:
# done.

# %%
wv.vis_weights_linear3x3(np_weights)

# %%
np_weights = wv.first_weight_linear(1)
print('done.')
# Out:
# done.

# %%
wv.vis_weights_linear3x3(np_weights)

# %% [markdown]
# ## Convolutional Layer Outputs

# %%
model = midlayer.load_mid_model(trained=True)
x = midlayer.load_image()
# Out:
# ['conv2d_1', 'activation_3', 'dropout_9', 'max_pooling2d_1', 'conv2d_2', 'activation_4', 'dropout_10', 'max_pooling2d_2', 'conv2d_3', 'activation_5', 'dropout_11', 'flatten_1', 'dense_13', 'dropout_12', 'dense_14']

# %%
midlayer.predict_plot(model, x)
# Out:
# (3, 28, 28, 16)

# %%
model = midlayer.load_mid_model(trained=False)
midlayer.predict_plot(model, x)
# Out:
# ['conv2d_4', 'activation_6', 'dropout_13', 'max_pooling2d_3', 'conv2d_5', 'activation_7', 'dropout_14', 'max_pooling2d_4', 'conv2d_6', 'activation_8', 'dropout_15', 'flatten_2', 'dense_15', 'dropout_16', 'dense_16']
# (3, 28, 28, 16)

# %% [markdown]
# ## Convolutional filter visiualization

# %%
np_array = wv.first_weight_conv()
wv.plot_conv_weights(np_array)

# %%
import conv_filter_visualization as cfv
from keras.applications import vgg16

# build the VGG16 network with ImageNet weights
vgg = vgg16.VGG16(weights='imagenet', include_top=False)
print('Model loaded.')
vgg.summary()

layer_names = [layer.name for layer in vgg.layers]
print(layer_names)

LAYER_NAME = 'block5_conv1'

cfv.visualize_layer(vgg, LAYER_NAME)
# Out:
# Model loaded.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# ['input_1', 'block1_conv1', 'block1_conv2', 'block1_pool', 'block2_conv1', 'block2_conv2', 'block2_pool', 'block3_conv1', 'block3_conv2', 'block3_conv3', 'block3_pool', 'block4_conv1', 'block4_conv2', 'block4_conv3', 'block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3', 'block5_pool']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-d4c97dcbd936> in <module>()
#      12 LAYER_NAME = 'block5_conv1'
#      13
# ---> 14 cfv.visualize_layer(model, LAYER_NAME)
#
# ~/Documents/Ankara_Üni/2_yuksek_lisans/visionlab/dl_demo/conv_filter_visualization.py in visualize_layer(model, layer_name, step, epochs, upscaling_steps, upscaling_factor, output_dim, filter_range)
#     218     layer_dict = dict([(layer.name, layer) for layer in model.layers[1:]])
#     219
# --> 220     output_layer = layer_dict[layer_name]
#     221     assert isinstance(output_layer, layers.Conv2D)
#     222
#
# KeyError: 'block5_conv1'
